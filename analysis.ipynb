# %% [markdown]
# <a href="https://colab.research.google.com/github/47096/talent-attrition/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install 'pycaret[full]' shap

# %%
# load data
import numpy as np
from pycaret.datasets import get_data

df = get_data('employee')

# %%
# set seed & split data into train and validation
np.random.seed(222)
msk = np.random.rand(len(df)) < 0.8

train = df[msk]
validation = df[~msk]

print(train.shape)
print(validation.shape)

# %%
# import classification module
from pycaret.classification import *

# intialize the setup (the session_id is like the seed for reproducibility)
int_setup = setup(data = train, target = 'left', session_id = 222)

# %%
# models available
models()

# %%
# compare models (full install enables xgboost etc.)
best = compare_models()
print(best)

# %%
# create a random forest model with 10 folds i.e. default setting
rf = create_model('rf')

# %%
# tune the model with default settings
# looks like the tunned model is not better than the original untuned model
tuned_rf = tune_model(rf)

# %%
# plot a model
plot_model(tuned_rf)

# %%
# evaluate a model
# this function is great but it takes a while to load the plot type when selected
evaluate_model(tuned_rf)

# %%
# interpret model (requires shap)
interpret_model(tuned_rf)

# %%
# score the held-out validation split (not PyCaret's internal test only)
tuned_rf_predictions_holdout = predict_model(tuned_rf, data=validation)

# %%
tuned_rf_predictions_holdout.head()

# %%
print(tuned_rf_predictions_holdout.shape)

# %%
tuned_rf

# %%
# finalize trained model on all available train data
final_model = finalize_model(tuned_rf)
final_model
